# %% [markdown]
# <a href="https://colab.research.google.com/github/charlottesscott/Breast_Screening_Uptake_Prediction/blob/main/01_Project_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Project Settings**
#
# Random State - sets a fixed random seed.
# Meaning: -
# *   Get the same train/test split every time
# *   Results are reproducible
#
# Test Size - determines what proportion of the dataset is held back for testing
# Meaning:-
# *   No overfitting
# *   No overestimating model performance
# *   Building a model athat works on real-world data
#
# Target - defines the outcome variable the model is trying to predict
# Means: -
# *   Only need to change it in one place

# %%
# Project settings

RANDOM_STATE = 42

TEST_SIZE = 0.2

TARGET = "low_uptake"
